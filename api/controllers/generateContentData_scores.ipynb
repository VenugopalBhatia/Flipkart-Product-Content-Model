# %%
import pandas as pd
import importlib
import report
importlib.reload(report)
# Out:
# <module 'report' from 'c:\\Users\\Administrator\\Desktop\\VGB\\flipkart_contentScores\\api\\controllers\\report.py'>

# %%
df = pd.read_excel('data/Philips_VCPM_FK_Products.xlsx',engine = 'openpyxl')

# %%
df_FlipkartCategoryData = df[['channel_sku_id','category','sub_category']]

# %%
ignore_keywords = ['norelco','aquatouch','satinshave']

# %%
report.genReport(df_FlipkartCategoryData,ignore_keywords)
# Out:
#   0%|          | 0/94 [00:00<?, ?it/s]
# 5/70 800 W Juicer (1 Jar, Black)
# PHILIPS HR1855/70 800 W Juicer (1 Jar, Black)
# PHILIPS HR1855/70 800 W Juicer (1 Jar, Black)
# PHILIPS HR1855/70 800 W Juicer (1 Jar, Black)
# PHILIPS HR1855/70 800 W Juicer (1 Jar, Black)
# PHILIPS HR1855/70 800 W Juicer (1 Jar, Black)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# PHILIPS Citrus Press HR2774 25 W Juicer (1 Jar, White)
# ...
